# %% [markdown]
# # Question 1& 2
# ## Titanic data is taken from kaggle

# %%
import pandas as pd
import numpy as np 
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df=pd.read_csv('train_and_test2.csv')
df
# Out:
#       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0               1  22.0    7.2500    0      1     0       0       0       0
# 1               2  38.0   71.2833    1      1     0       0       0       0
# 2               3  26.0    7.9250    1      0     0       0       0       0
# 3               4  35.0   53.1000    1      1     0       0       0       0
# 4               5  35.0    8.0500    0      0     0       0       0       0
# ...           ...   ...       ...  ...    ...   ...     ...     ...     ...
# 1304         1305  28.0    8.0500    0      0     0       0       0       0
# 1305         1306  39.0  108.9000    1      0     0       0       0       0
# 1306         1307  38.5    7.2500    0      0     0       0       0       0
# 1307         1308  28.0    8.0500    0      0     0       0       0       0
# 1308         1309  28.0   22.3583    0      1     0       0       0       0
#
# ...

# %%
#Make passenger ID as index
df1=df.set_index('Passengerid')
df1
# Out:
#               Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  zero.4  \
# Passengerid
# 1            22.0    7.2500    0      1     0       0       0       0       0
# 2            38.0   71.2833    1      1     0       0       0       0       0
# 3            26.0    7.9250    1      0     0       0       0       0       0
# 4            35.0   53.1000    1      1     0       0       0       0       0
# 5            35.0    8.0500    0      0     0       0       0       0       0
# ...           ...       ...  ...    ...   ...     ...     ...     ...     ...
# 1305         28.0    8.0500    0      0     0       0       0       0       0
# 1306         39.0  108.9000    1      0     0       0       0       0       0
# 1307         38.5    7.2500    0      0     0       0       0       0       0
# 1308         28.0    8.0500    0      0     0       0       0       0       0
# 1309         28.0   22.3583    0      1     0       0       0       0       0
#
# ...

# %%
#To delete columns with all zeros
df2 = df1.loc[:, (df != 0).any(axis=0)]
df2
# Out:
#               Age      Fare  Sex  sibsp  Parch  Pclass  Embarked  2urvived
# Passengerid
# 1            22.0    7.2500    0      1      0       3       2.0         0
# 2            38.0   71.2833    1      1      0       1       0.0         1
# 3            26.0    7.9250    1      0      0       3       2.0         1
# 4            35.0   53.1000    1      1      0       1       2.0         1
# 5            35.0    8.0500    0      0      0       3       2.0         0
# ...           ...       ...  ...    ...    ...     ...       ...       ...
# 1305         28.0    8.0500    0      0      0       3       2.0         0
# 1306         39.0  108.9000    1      0      0       1       0.0         0
# 1307         38.5    7.2500    0      0      0       3       2.0         0
# 1308         28.0    8.0500    0      0      0       3       2.0         0
# 1309         28.0   22.3583    0      1      1       3       0.0         0
#
# [1309 rows x 8 columns]

# %%
#Delete rows with missing values
df3 = df2[~np.isnan(df2).any(axis=1)]
df3
# Out:
#               Age      Fare  Sex  sibsp  Parch  Pclass  Embarked  2urvived
# Passengerid
# 1            22.0    7.2500    0      1      0       3       2.0         0
# 2            38.0   71.2833    1      1      0       1       0.0         1
# 3            26.0    7.9250    1      0      0       3       2.0         1
# 4            35.0   53.1000    1      1      0       1       2.0         1
# 5            35.0    8.0500    0      0      0       3       2.0         0
# ...           ...       ...  ...    ...    ...     ...       ...       ...
# 1305         28.0    8.0500    0      0      0       3       2.0         0
# 1306         39.0  108.9000    1      0      0       1       0.0         0
# 1307         38.5    7.2500    0      0      0       3       2.0         0
# 1308         28.0    8.0500    0      0      0       3       2.0         0
# 1309         28.0   22.3583    0      1      1       3       0.0         0
#
# [1307 rows x 8 columns]

# %%
# Summary statistics 
display(df3.describe())
# Out:
#                Age         Fare          Sex        sibsp        Parch  \
# count  1307.000000  1307.000000  1307.000000  1307.000000  1307.000000
# mean     29.471821    33.209595     0.355011     0.499617     0.385616
# std      12.881592    51.748768     0.478700     1.042273     0.866092
# min       0.170000     0.000000     0.000000     0.000000     0.000000
# 25%      22.000000     7.895800     0.000000     0.000000     0.000000
# 50%      28.000000    14.454200     0.000000     0.000000     0.000000
# 75%      35.000000    31.275000     1.000000     1.000000     0.000000
# max      80.000000   512.329200     1.000000     8.000000     9.000000
#
#             Pclass     Embarked     2urvived
# count  1307.000000  1307.000000  1307.000000
# mean      2.296863     1.492731     0.260138
# std       0.836942     0.814626     0.438877
# min       1.000000     0.000000     0.000000
# 25%       2.000000     1.000000     0.000000
# 50%       3.000000     2.000000     0.000000
# ...

# %%
# Mean, Median & Mode
meanData = df3.mean()
meanData
# Out:
# Age         29.471821
# Fare        33.209595
# Sex          0.355011
# sibsp        0.499617
# Parch        0.385616
# Pclass       2.296863
# Embarked     1.492731
# 2urvived     0.260138
# dtype: float64

# %%
medianData = df3.median()
medianData
# Out:
# Age         28.0000
# Fare        14.4542
# Sex          0.0000
# sibsp        0.0000
# Parch        0.0000
# Pclass       3.0000
# Embarked     2.0000
# 2urvived     0.0000
# dtype: float64

# %%
modeData = df3.mode()
modeData
# Out:
#     Age  Fare  Sex  sibsp  Parch  Pclass  Embarked  2urvived
# 0  28.0  8.05    0      0      0       3       2.0         0

# %%
df3.hist(figsize=(10,10),bins=10)
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Fare'}>,
#         <AxesSubplot:title={'center':'Sex'}>],
#        [<AxesSubplot:title={'center':'sibsp'}>,
#         <AxesSubplot:title={'center':'Parch'}>,
#         <AxesSubplot:title={'center':'Pclass'}>],
#        [<AxesSubplot:title={'center':'Embarked'}>,
#         <AxesSubplot:title={'center':'2urvived'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ## From the above data analysis and visualizations it can be concluded that
# ### Sex, Pclass, Embarked, Survived are categorical variables.
# ### Standard deviation is more for age and fare that indicate data is widely distributed from mean.
# ### Mean, Median, Mode is almost same for Sex variable hence distribution will be more close to normal distribution.
# ### Mean, Median & Mode for parameters Fare, sibsp, Parch have large difference. Hence these distributions will be more skewed.

# %%
# Correlation matrix
corrMatrix = df3.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# ### No pair of parameters have the strong correlation.
# ### Highest correlation is -0.56 between Pclass and Fare.
# ### 2nd highest correlation is -0.38 between Pclass and Age.

# %% [markdown]
# ## Question-3:
# ### Data considered is microsoft annual revenue vs average stock price for that year.
# ### From year 2005 to 2021.

# %%
DF=pd.read_excel('MSrevenue.xlsx')
DF
# Out:
#     Year  Total Revenue  Average Stock price
# 0   2005          39788            25.871270
# 1   2006          44282            26.290359
# 2   2007          51122            30.446773
# 3   2008          60420            26.647391
# 4   2009          58437            22.976786
# 5   2010          62484            27.058571
# 6   2011          69943            26.052341
# 7   2012          73723            29.820960
# 8   2013          77849            32.491905
# 9   2014          86833            42.453492
# 10  2015          93580            46.714286
# 11  2016          91154            55.259325
# 12  2017          96571            71.984024
# 13  2018         110360           101.033984
# 14  2019         125843           130.382024
# 15  2020         143015           193.026126
# 16  2021         168088           275.940754

# %%
DF.plot( 'Year' , 'Total Revenue' )
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
DF.plot( 'Year' , 'Average Stock price' )
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# # Question-4
#
# ### Supervised learning business problem:
#
# AI recommender system to detect the fraudulent banking transactions:
#
# Banking transactions per day very huge in number it is impossible to monitor and prevent by humans.
#
# When we have past data labeled with fraudulent and non fraudulent transactions using supervised learning models we can predict which real time transaction could be fraudulent.
#
# Data used for these models may include transaction amount, merchant, payment method, location, number of failed attempts etc.
#
# Using classification models like logistic regression or binary tree classification predictions can be done.

# %% [markdown]
# # Question-4
# ### Reinforcement learning - business problem:¶
# Automatic driving car without human intervention:
#
# Complex coding tasks like auto driving, gaming etc. can be modelled by reinforcement learning method without being explicitly coded. One more advantage for this model is no previous test data required.
#
# Object learns from actions performed in an environment based on reward received.
#
# For the example of driving, car is the object. Environment is road, signals, other vehicles around and instructions from maps etc.
# reward function should be designed such a way that when car drive as desired it will receive highest reward.
# If it perform wrong action, based on the mistake proportionate reward function will cut down.
#
# With this trail and error actions model trains and it remembers good actions where it got highest reward function and always tries to repeat them.
